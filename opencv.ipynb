# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhankar-mern/MLBasicsLearn/blob/master/opencv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###open cv

# %%
import cv2

# %%
## read and write imagesinput avideo stream

# %%
img= cv2.imread('/content/450-3890x1440.jpg')
newImg = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(newImg)
plt.show()
plt.imshow(img)
plt.show()
